# %%
from keras import models
from keras import layers
from keras import optimizers
from keras import metrics
from keras import losses
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.utils import np_utils

(train_images, train_labels), (test_images, test_labels)=mnist.load_data()
train_images=train_images.reshape((60000, 28*28))
train_images=train_images.astype('float32')/255

test_images=test_images.reshape((10000, 28*28))
test_images=test_images.astype('float32')/255

train_labels=np_utils.to_categorical(train_labels, 10)
test_labels=np_utils.to_categorical(test_labels, 10)

network=models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(784, )))
network.add(layers.Dense(10, activation='softmax'))

network.compile(optimizer='rmsprop', 
               loss ='categorical_crossentropy',
               metrics=['accuracy'])

network.fit(train_images, train_labels, epochs=20, batch_size=128)
# Out:
# Epoch 1/20
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.2595 - acc: 0.9243
# Epoch 2/20
# 60000/60000 [==============================] - 5s 77us/step - loss: 0.1060 - acc: 0.9689
# Epoch 3/20
# 60000/60000 [==============================] - 5s 79us/step - loss: 0.0701 - acc: 0.9797
# Epoch 4/20
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0508 - acc: 0.9851
# Epoch 5/20
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0387 - acc: 0.9887
# Epoch 6/20
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0292 - acc: 0.9912
# Epoch 7/20
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0222 - acc: 0.9933
# Epoch 8/20
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0177 - acc: 0.9947
# Epoch 9/20
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0135 - acc: 0.9960
# Epoch 10/20
# 60000/60000 [==============================] - 4s 75us/step - loss: 0.0104 - acc: 0.9969
# Epoch 11/20
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0078 - acc: 0.9979
# Epoch 12/20
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0066 - acc: 0.9983
# Epoch 13/20
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0051 - acc: 0.9987
# Epoch 14/20
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0043 - acc: 0.9988
# Epoch 15/20
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0029 - acc: 0.9993
# Epoch 16/20
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0027 - acc: 0.9993
# Epoch 17/20
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0020 - acc: 0.9995
# Epoch 18/20
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0016 - acc: 0.9997
# Epoch 19/20
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0014 - acc: 0.9997
# Epoch 20/20
# 60000/60000 [==============================] - 5s 76us/step - loss: 0.0011 - acc: 0.9997
